# %% [markdown]
# # Gago Glazers – Exploratory Data Analysis
#
# Dataset: Top 10K Spotify Songs (2025-07 detailed).

# %%
import pandas as pd
from pathlib import Path

data_path = Path("../top-10k-spotify-songs-2025-07-detailed.csv")
if not data_path.exists():
    data_path = Path("../data/raw/top-10k-spotify-songs-2025-07-detailed.csv")
df = pd.read_csv(data_path)
df.head()
